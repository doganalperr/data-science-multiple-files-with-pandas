# %% [markdown]
# # `pandas` ile birden fazla dosya

# %%
# %pip install matplotlib

import numpy as np
import pandas as pd
import matplotlib
# Out:
# Requirement already satisfied: matplotlib in /home/doganalper/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /home/doganalper/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/doganalper/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/doganalper/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/doganalper/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /home/doganalper/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/doganalper/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/doganalper/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /home/doganalper/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/doganalper/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/doganalper/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Merge Alıştırması

# %%
a_df = pd.DataFrame({
    'Country': ['Germany', 'France', 'Belgium', 'Finland'],
    'Population (M)': [82.8, 67.2, 11.4, 5.5],
    'Capital': ['Berlin', 'Paris', 'Brussels', 'Helsinki']
})
a_df
# Out:
#    Country  Population (M)   Capital
# 0  Germany            82.8    Berlin
# 1   France            67.2     Paris
# 2  Belgium            11.4  Brussels
# 3  Finland             5.5  Helsinki

# %%
b_df = pd.DataFrame({
    'Country': ['Germany', 'France', 'Belgium', 'Canada'],
    'HDI': [0.936, 0.901, 0.916, 0.926]
})
b_df
# Out:
#    Country    HDI
# 0  Germany  0.936
# 1   France  0.901
# 2  Belgium  0.916
# 3   Canada  0.926

# %% [markdown]
# ### İç Birleştirme Alıştırması

# %%
inner_merged_df = pd.merge(a_df, b_df, on="Country")
inner_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916

# %% [markdown]
# #### Kodunu kontrol et

# %%
from nbresult import ChallengeResult

result = ChallengeResult('inner_merge',
    inner_merged_shape=inner_merged_df.shape,
    inner_merged_nulls=sum(inner_merged_df.isnull().sum())
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.9, pytest-8.3.4, pluggy-1.6.0 -- /home/doganalper/.pyenv/versions/3.12.9/envs/langchain-env/bin/python
# cachedir: .pytest_cache
# rootdir: /home/doganalper/code/data-science-multiple-files-with-pandas
# configfile: pytest.ini
# plugins: anyio-4.12.1, langsmith-0.5.0
# collecting ... collected 2 items
#
# test_inner_merge.py::TestInnerMerge::test_inner_merged_nulls PASSED      [ 50%]
# test_inner_merge.py::TestInnerMerge::test_inner_merged_shape PASSED      [100%]
#
# ============================== 2 passed in 0.01s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/inner_merge.pickle
#
# git commit -m 'Completed inner_merge step'
#
# git push origin master

# %% [markdown]
# ### Sol Birleştirme Alıştırması

# %%
left_merged_df = pd.merge(a_df,b_df, on="Country", how="left")
left_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916
# 3  Finland             5.5  Helsinki    NaN

# %% [markdown]
# #### Kodunu kontrol et

# %%
from nbresult import ChallengeResult

result = ChallengeResult('left_merge',
    left_merged_shape=left_merged_df.shape,
    left_merged_nulls=sum(left_merged_df.isnull().sum())
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.9, pytest-8.3.4, pluggy-1.6.0 -- /home/doganalper/.pyenv/versions/3.12.9/envs/langchain-env/bin/python
# cachedir: .pytest_cache
# rootdir: /home/doganalper/code/data-science-multiple-files-with-pandas
# configfile: pytest.ini
# plugins: anyio-4.12.1, langsmith-0.5.0
# collecting ... collected 2 items
#
# test_left_merge.py::TestLeftMerge::test_left_merged_df_shape PASSED      [ 50%]
# test_left_merge.py::TestLeftMerge::test_left_merged_nulls PASSED         [100%]
#
# ============================== 2 passed in 0.01s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/left_merge.pickle
#
# git commit -m 'Completed left_merge step'
#
# git push origin master

# %% [markdown]
# ### Sağ Birleştirme Alıştırması

# %%
right_merged_df = pd.merge(a_df,b_df, on="Country", how="right")
right_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916
# 3   Canada             NaN       NaN  0.926

# %% [markdown]
# #### Kodunu kontrol et

# %%
from nbresult import ChallengeResult

result = ChallengeResult('right_merge',
    right_merged_shape=right_merged_df.shape,
    right_merged_nulls=sum(right_merged_df.isnull().sum())
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.9, pytest-8.3.4, pluggy-1.6.0 -- /home/doganalper/.pyenv/versions/3.12.9/envs/langchain-env/bin/python
# cachedir: .pytest_cache
# rootdir: /home/doganalper/code/data-science-multiple-files-with-pandas
# configfile: pytest.ini
# plugins: anyio-4.12.1, langsmith-0.5.0
# collecting ... collected 2 items
#
# test_right_merge.py::TestRightMerge::test_right_merged_df_shape PASSED   [ 50%]
# test_right_merge.py::TestRightMerge::test_right_merged_nulls PASSED      [100%]
#
# ============================== 2 passed in 0.01s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/right_merge.pickle
#
# git commit -m 'Completed right_merge step'
#
# git push origin master

# %% [markdown]
# ### Dış Birleştirme Alıştırması

# %%
outer_merged_df = pd.merge(a_df,b_df, on="Country", how="outer")
outer_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Belgium            11.4  Brussels  0.916
# 1   Canada             NaN       NaN  0.926
# 2  Finland             5.5  Helsinki    NaN
# 3   France            67.2     Paris  0.901
# 4  Germany            82.8    Berlin  0.936

# %% [markdown]
# #### Kodunu kontrol et

# %%
from nbresult import ChallengeResult

result = ChallengeResult('outer_merge',
    outer_merged_shape=outer_merged_df.shape,
    outer_merged_nulls=sum(outer_merged_df.isnull().sum())
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.9, pytest-8.3.4, pluggy-1.6.0 -- /home/doganalper/.pyenv/versions/3.12.9/envs/langchain-env/bin/python
# cachedir: .pytest_cache
# rootdir: /home/doganalper/code/data-science-multiple-files-with-pandas
# configfile: pytest.ini
# plugins: anyio-4.12.1, langsmith-0.5.0
# collecting ... collected 2 items
#
# test_outer_merge.py::TestOuterMerge::test_outer_merged_df_shape PASSED   [ 50%]
# test_outer_merge.py::TestOuterMerge::test_outer_merged_nulls PASSED      [100%]
#
# ============================== 2 passed in 0.01s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/outer_merge.pickle
#
# git commit -m 'Completed outer_merge step'
#
# git push origin master

# %% [markdown]
# ## Join Alıştırması

# %%
aa_df = a_df.set_index("Country")
aa_df
# Out:
#          Population (M)   Capital
# Country
# Germany            82.8    Berlin
# France             67.2     Paris
# Belgium            11.4  Brussels
# Finland             5.5  Helsinki

# %%
bb_df = b_df.set_index("Country")
bb_df
# Out:
#            HDI
# Country
# Germany  0.936
# France   0.901
# Belgium  0.916
# Canada   0.926

# %%
aa_df.join(bb_df)
# Out:
#          Population (M)   Capital    HDI
# Country
# Germany            82.8    Berlin  0.936
# France             67.2     Paris  0.901
# Belgium            11.4  Brussels  0.916
# Finland             5.5  Helsinki    NaN

# %%
aa_df.join(bb_df, how='inner')
# Out:
#          Population (M)   Capital    HDI
# Country
# Germany            82.8    Berlin  0.936
# France             67.2     Paris  0.901
# Belgium            11.4  Brussels  0.916

# %%
aa_df.join(bb_df, how='right')
# Out:
#          Population (M)   Capital    HDI
# Country
# Germany            82.8    Berlin  0.936
# France             67.2     Paris  0.901
# Belgium            11.4  Brussels  0.916
# Canada              NaN       NaN  0.926

# %%
aa_df.join(bb_df, how='outer')
# Out:
#          Population (M)   Capital    HDI
# Country
# Belgium            11.4  Brussels  0.916
# Canada              NaN       NaN  0.926
# Finland             5.5  Helsinki    NaN
# France             67.2     Paris  0.901
# Germany            82.8    Berlin  0.936

# %% [markdown]
# ## Concat Alıştırması

# %%
concat_df = pd.concat([a_df, b_df], axis="index", sort=False)
concat_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin    NaN
# 1   France            67.2     Paris    NaN
# 2  Belgium            11.4  Brussels    NaN
# 3  Finland             5.5  Helsinki    NaN
# 0  Germany             NaN       NaN  0.936
# 1   France             NaN       NaN  0.901
# 2  Belgium             NaN       NaN  0.916
# 3   Canada             NaN       NaN  0.926

# %% [markdown]
# ## Olympic Sports and Medals, 1896-2014

# %%
countries_df = pd.read_csv('dictionary.csv')
summer_df = pd.read_csv('summer.csv')
winter_df = pd.read_csv('winter.csv')


countries_df.head()
# Out:
#            Country Code  Population  GDP per Capita
# 0      Afghanistan  AFG  32526562.0      594.323081
# 1          Albania  ALB   2889167.0     3945.217582
# 2          Algeria  ALG  39666519.0     4206.031232
# 3  American Samoa*  ASA     55538.0             NaN
# 4          Andorra  AND     70473.0             NaN

# %%
summer_df = summer_df.rename(columns={'Country': 'Code'})
winter_df = winter_df.rename(columns={'Country': 'Code'})

summer_df.head()
# Out:
#    Year    City     Sport Discipline             Athlete Code Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %% [markdown]
# ### Verileri Birleştirme

# %%
summer_countries_df = pd.merge(summer_df, countries_df, on="Code", how="inner")
summer_countries_df["Season"] = "Summer"

winter_countries_df = pd.merge(winter_df, countries_df, on="Code", how="inner")
winter_countries_df["Season"] = "Winter"

all_df = pd.concat([summer_countries_df, winter_countries_df], ignore_index=True)

all_df.head()
# Out:
#    Year    City     Sport Discipline             Athlete Code Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event   Medal  Country  Population  GDP per Capita  \
# 0              100M Freestyle    Gold  Hungary   9844686.0    12363.543460
# 1              100M Freestyle  Silver  Austria   8611088.0    43774.985174
# 2  100M Freestyle For Sailors  Bronze   Greece  10823732.0    18002.230578
# 3  100M Freestyle For Sailors    Gold   Greece  10823732.0    18002.230578
# 4  100M Freestyle For Sailors  Silver   Greece  10823732.0    18002.230578
#
#    Season
# 0  Summer
# 1  Summer
# 2  Summer
# 3  Summer
# 4  Summer

# %% [markdown]
# #### Kodunu kontrol et

# %%
from nbresult import ChallengeResult

result = ChallengeResult('all_df',
    all_df_shape=all_df.shape,
    all_df_columns=set(all_df.columns)
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.9, pytest-8.3.4, pluggy-1.6.0 -- /home/doganalper/.pyenv/versions/3.12.9/envs/langchain-env/bin/python
# cachedir: .pytest_cache
# rootdir: /home/doganalper/code/data-science-multiple-files-with-pandas
# configfile: pytest.ini
# plugins: anyio-4.12.1, langsmith-0.5.0
# collecting ... collected 2 items
#
# test_all_df.py::TestAllDf::test_all_df_columns PASSED                    [ 50%]
# test_all_df.py::TestAllDf::test_all_df_shape PASSED                      [100%]
#
# ============================== 2 passed in 0.01s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/all_df.pickle
#
# git commit -m 'Completed all_df step'
#
# git push origin master

# %% [markdown]
# ### En Başarılı Ülkeler Analizi

# %%
after_1984_df = all_df[all_df["Year"] >= 1984]

top_10_df = after_1984_df.groupby("Country")[["Medal"]].count()
top_10_df.columns = ["Medal Count"]

top_10_df = top_10_df.sort_values(by="Medal Count", ascending=False).head(10)

top_10_df.plot(kind="bar");

# %% [markdown]
# #### Kodunu kontrol et

# %%
from nbresult import ChallengeResult

result = ChallengeResult('olympic_games',
    top_country_1=top_10_df.iloc[0]['Medal Count'],
    top_country_10=top_10_df.iloc[9]['Medal Count']
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.9, pytest-8.3.4, pluggy-1.6.0 -- /home/doganalper/.pyenv/versions/3.12.9/envs/langchain-env/bin/python
# cachedir: .pytest_cache
# rootdir: /home/doganalper/code/data-science-multiple-files-with-pandas
# configfile: pytest.ini
# plugins: anyio-4.12.1, langsmith-0.5.0
# collecting ... collected 1 item
#
# test_olympic_games.py::TestOlympicGames::test_top_10_countries_medals PASSED [100%]
#
# ============================== 1 passed in 0.08s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/olympic_games.pickle
#
# git commit -m 'Completed olympic_games step'
#
# git push origin master

# %%
season_group = after_1984_df.groupby(["Country", "Season"])[["Medal"]].count()

top_10_season_df = season_group.unstack()

top_10_season_df.columns = ["Summer","Winter"]
top_10_season_df = top_10_season_df.fillna(0)

top_10_season_df["Total"] = top_10_season_df["Summer"] + top_10_season_df["Winter"]

top_10_season_df = top_10_season_df.sort_values(by="Total", ascending=False).head(10)

top_10_season_df[['Summer', 'Winter']].plot(kind="bar", stacked=False, figsize=(10,6));

# %% [markdown]
# #### Kodunu kontrol et

# %%
from nbresult import ChallengeResult

result = ChallengeResult('olympic_games_season',
    top_country_season_shape=top_10_season_df.shape,
    top_country_1_summer=top_10_season_df.iloc[0]['Summer'],
    top_country_10_winter=top_10_season_df.iloc[9]['Winter']
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.9, pytest-8.3.4, pluggy-1.6.0 -- /home/doganalper/.pyenv/versions/3.12.9/envs/langchain-env/bin/python
# cachedir: .pytest_cache
# rootdir: /home/doganalper/code/data-science-multiple-files-with-pandas
# configfile: pytest.ini
# plugins: anyio-4.12.1, langsmith-0.5.0
# collecting ... collected 3 items
#
# test_olympic_games_season.py::TestOlympicGamesSeason::test_top_10_countries_shape PASSED [ 33%]
# test_olympic_games_season.py::TestOlympicGamesSeason::test_top_10_countries_summer PASSED [ 66%]
# test_olympic_games_season.py::TestOlympicGamesSeason::test_top_10_countries_winter PASSED [100%]
#
# ============================== 3 passed in 0.09s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/olympic_games_season.pickle
#
# git commit -m 'Completed olympic_games_season step'
#
# git push origin master

# %%
all_df[(all_df.Year==2008) & (all_df.Event=='Basketball') & (all_df.Medal=='Gold')]
# Out:
#        Year     City       Sport  Discipline                Athlete Code  \
# 22493  2008  Beijing  Basketball  Basketball       ANTHONY, Carmelo  USA
# 22494  2008  Beijing  Basketball  Basketball         BOOZER, Carlos  USA
# 22495  2008  Beijing  Basketball  Basketball            BOSH, Chris  USA
# 22496  2008  Beijing  Basketball  Basketball           BRYANT, Kobe  USA
# 22497  2008  Beijing  Basketball  Basketball         HOWARD, Dwight  USA
# 22498  2008  Beijing  Basketball  Basketball          JAMES, Lebron  USA
# 22499  2008  Beijing  Basketball  Basketball            KIDD, Jason  USA
# 22500  2008  Beijing  Basketball  Basketball            PAUL, Chris  USA
# 22501  2008  Beijing  Basketball  Basketball       PRINCE, Tayshaun  USA
# 22502  2008  Beijing  Basketball  Basketball          REDD, Michael  USA
# 22503  2008  Beijing  Basketball  Basketball           WADE, Dwyane  USA
# 22504  2008  Beijing  Basketball  Basketball        WILLIAMS, Deron  USA
# 22529  2008  Beijing  Basketball  Basketball      AUGUSTUS, Seimone  USA
# 22530  2008  Beijing  Basketball  Basketball              BIRD, Sue  USA
# 22531  2008  Beijing  Basketball  Basketball      CATCHINGS, Tamika  USA
# 22532  2008  Beijing  Basketball  Basketball         FOWLES, Sylvia  USA
# 22533  2008  Beijing  Basketball  Basketball           LAWSON, Kara  USA
# 22534  2008  Beijing  Basketball  Basketball           LESLIE, Lisa  USA
# 22535  2008  Beijing  Basketball  Basketball  MILTON-JONES, Delisha  USA
# 22536  2008  Beijing  Basketball  Basketball        PARKER, Candace  USA
# 22537  2008  Beijing  Basketball  Basketball      PONDEXTER, Cappie  USA
# 22538  2008  Beijing  Basketball  Basketball           SMITH, Katie  USA
# 22539  2008  Beijing  Basketball  Basketball         TAURASI, Diana  USA
# 22540  2008  Beijing  Basketball  Basketball         THOMPSON, Tina  USA
#
#       Gender       Event Medal        Country   Population  GDP per Capita  \
# 22493    Men  Basketball  Gold  United States  321418820.0    56115.718426
# 22494    Men  Basketball  Gold  United States  321418820.0    56115.718426
# 22495    Men  Basketball  Gold  United States  321418820.0    56115.718426
# 22496    Men  Basketball  Gold  United States  321418820.0    56115.718426
# 22497    Men  Basketball  Gold  United States  321418820.0    56115.718426
# 22498    Men  Basketball  Gold  United States  321418820.0    56115.718426
# 22499    Men  Basketball  Gold  United States  321418820.0    56115.718426
# 22500    Men  Basketball  Gold  United States  321418820.0    56115.718426
# 22501    Men  Basketball  Gold  United States  321418820.0    56115.718426
# 22502    Men  Basketball  Gold  United States  321418820.0    56115.718426
# 22503    Men  Basketball  Gold  United States  321418820.0    56115.718426
# 22504    Men  Basketball  Gold  United States  321418820.0    56115.718426
# 22529  Women  Basketball  Gold  United States  321418820.0    56115.718426
# 22530  Women  Basketball  Gold  United States  321418820.0    56115.718426
# 22531  Women  Basketball  Gold  United States  321418820.0    56115.718426
# 22532  Women  Basketball  Gold  United States  321418820.0    56115.718426
# 22533  Women  Basketball  Gold  United States  321418820.0    56115.718426
# 22534  Women  Basketball  Gold  United States  321418820.0    56115.718426
# 22535  Women  Basketball  Gold  United States  321418820.0    56115.718426
# 22536  Women  Basketball  Gold  United States  321418820.0    56115.718426
# 22537  Women  Basketball  Gold  United States  321418820.0    56115.718426
# 22538  Women  Basketball  Gold  United States  321418820.0    56115.718426
# 22539  Women  Basketball  Gold  United States  321418820.0    56115.718426
# 22540  Women  Basketball  Gold  United States  321418820.0    56115.718426
#
#        Season
# 22493  Summer
# 22494  Summer
# 22495  Summer
# 22496  Summer
# 22497  Summer
# 22498  Summer
# 22499  Summer
# 22500  Summer
# 22501  Summer
# 22502  Summer
# 22503  Summer
# 22504  Summer
# 22529  Summer
# 22530  Summer
# 22531  Summer
# 22532  Summer
# 22533  Summer
# 22534  Summer
# 22535  Summer
# 22536  Summer
# 22537  Summer
# 22538  Summer
# 22539  Summer
# 22540  Summer

# %%
cleaned_df = after_1984_df.drop(columns=["Athlete", "Gender"])

events_df = cleaned_df.drop_duplicates()

top_10_events_df = events_df.groupby("Country")[["Medal"]].count()

top_10_events_df.columns = ["Event Count"]

top_10_events_df = top_10_events_df.sort_values(by='Event Count', ascending=False).head(10)

top_10_events_df.plot(kind='bar', color='orange', figsize=(10,6));

# %% [markdown]
# #### Kodunu kontrol et

# %%
from nbresult import ChallengeResult

result = ChallengeResult('olympic_games_event',
    top_country_event_shape=top_10_events_df.shape,
    top_country_1_event=top_10_events_df.iloc[0]['Event Count'],
    top_country_10_event=top_10_events_df.iloc[9]['Event Count']
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.9, pytest-8.3.4, pluggy-1.6.0 -- /home/doganalper/.pyenv/versions/3.12.9/envs/langchain-env/bin/python
# cachedir: .pytest_cache
# rootdir: /home/doganalper/code/data-science-multiple-files-with-pandas
# configfile: pytest.ini
# plugins: anyio-4.12.1, langsmith-0.5.0
# collecting ... collected 3 items
#
# test_olympic_games_event.py::TestOlympicGamesEvent::test_top_10_events_shape PASSED [ 33%]
# test_olympic_games_event.py::TestOlympicGamesEvent::test_top_events_1 PASSED [ 66%]
# test_olympic_games_event.py::TestOlympicGamesEvent::test_top_events_10 PASSED [100%]
#
# ============================== 3 passed in 0.09s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/olympic_games_event.pickle
#
# git commit -m 'Completed olympic_games_event step'
#
# git push origin master

# %%
top_10_combined = top_10_df.merge(top_10_events_df, left_index=True, right_index=True, how='outer')

top_10_combined = top_10_combined.sort_values(by="Medal Count", ascending=False)

top_10_combined.plot(kind='bar', figsize=(12,6), title="Medal Count vs Event Count (Since 1984)");

# %% [markdown]
# #### Kodunu kontrol et

# %%
from nbresult import ChallengeResult

result = ChallengeResult('olympic_games_combined',
    top_combined_shape=top_10_combined.shape,
    top_combined_1_event=top_10_combined.iloc[0]['Event Count'],
    top_combined_1_medal=top_10_combined.iloc[0]['Medal Count'],
    top_combined_10_event=top_10_combined.iloc[9]['Event Count'],
    top_combined_10_medal=top_10_combined.iloc[9]['Medal Count']
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.9, pytest-8.3.4, pluggy-1.6.0 -- /home/doganalper/.pyenv/versions/3.12.9/envs/langchain-env/bin/python
# cachedir: .pytest_cache
# rootdir: /home/doganalper/code/data-science-multiple-files-with-pandas
# configfile: pytest.ini
# plugins: anyio-4.12.1, langsmith-0.5.0
# collecting ... collected 3 items
#
# test_olympic_games_combined.py::TestOlympicGamesCombined::test_combined_1 PASSED [ 33%]
# test_olympic_games_combined.py::TestOlympicGamesCombined::test_combined_10 PASSED [ 66%]
# test_olympic_games_combined.py::TestOlympicGamesCombined::test_top_10_combined_shape PASSED [100%]
#
# ============================== 3 passed in 0.09s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/olympic_games_combined.pickle
#
# git commit -m 'Completed olympic_games_combined step'
#
# git push origin master
